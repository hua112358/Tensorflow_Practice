# %%
# 1 单词的表征方式
# 1.1 one-hot
# 1.2 词嵌入（词向量）

# 2 one-hot的缺点
# 2.1 维度高，计算量大
# 2.2 不能反映单词间的联系和相似度

# 3 词嵌入
# 3.1 用一个词嵌入矩阵， 把单词表示成一个较低维度的向量
# 3.2 向量的每个维度代表单词的一个属性特征，如是否是名词、是否是食物、是否以a开头
# 3.3 这些维度不是人为规定的，而是算法学习到的

# 4 Word2Vec
# 4.1 Word2Vec是一种学习词嵌入矩阵的算法
# 4.2 包括两种模式：CBOW，skip_gram
# 4.3 CBOW：由中心词周围的词（Contex）预测中心词（Target）
# 4.4 skip_gram：由中心词（Target）预测中心词周围的词（Context）
# 4.5 skip_gram具体步骤：
# 4.5.1 将文本中的每个词用one-hot向量表示
# 4.5.2 初始化一个词嵌入矩阵，将文本转换为词向量表示
# 4.5.3 中心词作为输入，中心词周围skip_window内取num_skips的词作为真实输出，得到num_skips组样本，依次滑动窗口，遍历所有文本
# 4.5.4 通过线性神经元和softmax激活函数将输入转换为预测值
# 4.5.5 计算损失函数，最小化后得到最优词嵌入矩阵

# %%
import collections
import math
import os
import random
import zipfile
import numpy as np
import urllib
import tensorflow as tf

# %%
# 下载数据
url = "http://mattmahoney.net/dc"

def maybe_download(filename, expected_bytes):
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url+filename, filename)
    stat_info = os.stat(filename)
    if stat_info.st_size == expected_bytes:
        print("Found and verified", filename)
    else:
        print(stat_info.str_size)
        raise Exception("Failed to verif"+filename+". Can you get it with a browser?")
    return filename

filename = maybe_download("text8.zip", 31344016)
# Out:
# Found and verified text8.zip

# %%
# 读取数据
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print("Datasize", len(words))
# Out:
# Datasize 17005207

# %%
# 将原始数据转换成索引形式，tf.nn.embedding_lookup会将索引转化成为词向量
vocabulary_size = 50000

def build_dataset(words):
    count = [["UNK", -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)

# %%
del words
print("Most common words (+UNK)", count[:5])
print("Sample data", data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# 生成训练集
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size%num_skips == 0
    assert num_skips <= 2*skip_window
    batch = np.ndarray(shape=(batch_size, ), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2*skip_window+1
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index+1)%len(data)
        
    for i in range(batch_size//num_skips):
        target = skip_window 
        target_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in target_to_avoid:
                target = random.randint(0, span-1)
            target_to_avoid.append(target)
            batch[i*num_skips+j] = buffer[skip_window]
            labels[i*num_skips+j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index+1)%len(data)
    return batch, labels

# %%
batch, labels = generate_batch(8, 2, 1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], "->", labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# 定义相关参数
batch_size = 128
embedding_size = 128
skip_window = 1
num_skips = 2

valid_size = 16
valid_window = 100
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64

# %%
# 构建计算图
graph = tf.Graph()
with graph.as_default():
    # train_inputs = (128, )
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    # train_labels = (128, 1)
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    # valid_dataset = (16, )
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    with tf.device("/cpu:0"):
        # embeddings = (50000, 128)
        embeddings = tf.Variable(tf.random_normal([vocabulary_size, embedding_size], -1.0, 1.0))
        # embed = (128, 128)，前128代表样本索引，后128代表属性特征索引
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        
        # nce_weights = (50000, 128)
        nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                      stddev=1.0/math.sqrt(embedding_size)))
        
        # nce_biases = (50000, )
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights, 
                                            biases=nce_biases, 
                                            labels=train_labels, 
                                            inputs=embed, 
                                            num_sampled=num_sampled, 
                                            num_classes=vocabulary_size))
        
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
        # norm = (50000, 1)
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        # normlized_embeddings = (50000, 128)
        normalized_embeddings = embeddings/norm
        # valid_embeddings = (16, 128)
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        # similarity = (16, 50000)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
        
        init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-11-c552c68f70c7>:23: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    init.run()
    print("Initialized")
    
    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs:batch_inputs, train_labels:batch_labels}
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
    
        if step%1000==0:
            if step>0:
                average_loss /= 2000
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0
            
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s, " % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  267.3464050292969
# Nearest to was: secure,  butte,  bayezid,  doctrine,  undertaken,  plume,  hsbc,  hutchins,
# Nearest to one: concerted,  tata,  overseer,  ax,  theses,  anselm,  muslim,  overpowered,
# Nearest to in: slavery,  manifestation,  blasting,  karenga,  disposal,  improperly,  taliaferro,  allowable,
# Nearest to th: kuwaiti,  enciphered,  limb,  gwh,  blind,  lir,  courtyards,  vengeful,
# Nearest to would: consular,  cathal,  iir,  elite,  profiles,  segments,  mythological,  arsenate,
# Nearest to been: poodle,  jovian,  recovered,  bjelke,  barbuda,  opportunity,  overdosing,  hasmonaean,
# Nearest to zero: ratzinger,  unravel,  almanac,  ferromagnetism,  nadezhda,  wealthy,  norm,  gamer,
# Nearest to who: detonator,  unhealthy,  deciding,  inaccessible,  airshow,  helices,  ssn,  approximating,
# Nearest to UNK: montego,  restaurant,  ebbinghaus,  overtones,  accordions,  clausius,  lackluster,  limestone,
# Nearest to an: flavored,  phimosis,  secretaries,  etienne,  storied,  arpanet,  consecrations,  milestone,
# Nearest to known: sha,  vivant,  shade,  nellie,  petty,  resumed,  paddy,  schwerin,
# Nearest to however: loomis,  shaolin,  paces,  rupee,  kessler,  caston,  praxis,  braves,
# Nearest to are: predictions,  cdma,  dit,  announcers,  tata,  mating,  receded,  drab,
# Nearest to system: diamond,  fulk,  clipped,  aldrich,  raphaelite,  scoring,  maynooth,  caucasus,
# Nearest to over: sea,  rockstar,  allow,  hp,  mattingly,  goldbach,  sistine,  kournikova,
# Nearest to eight: projectors,  xxviii,  sheltered,  unintentional,  demoralized,  traumas,  fgm,  maladaptive,
# Average loss at step  1000 :  75.26532511520385
# Nearest to was: secure,  plume,  doctrine,  alberoni,  intact,  claus,  nouveaux,  subsumed,
# Nearest to one: marksman,  pwn,  mur,  elca,  validated,  in,  yang,  claimant,
# Nearest to in: macos,  s,  outpouring,  knesset,  reuter,  beaton,  pigmented,  blasting,
# Nearest to th: kuwaiti,  enciphered,  limb,  lir,  gwh,  blind,  courtyards,  dahmer,
# Nearest to would: absorbed,  stamping,  consular,  segments,  goon,  cs,  focussing,  fame,
# Nearest to been: jovian,  recovered,  nic,  zseries,  bjelke,  hasmonaean,  freehold,  schleswig,
# Nearest to zero: wai,  crafty,  tina,  camps,  borrowing,  rooney,  carrey,  allomorphy,
# Nearest to who: detonator,  cornwall,  approximating,  highness,  sulfides,  wco,  airplanes,  murbella,
# Nearest to UNK: the,  drummers,  restaurant,  coq,  montego,  nicknamed,  subsidiaries,  subtropical,
# Nearest to an: elisha,  feature,  bam,  aclu,  portrayed,  etienne,  vig,  runaway,
# Nearest to known: sha,  resumed,  vivant,  schwerin,  shade,  matched,  xm,  nellie,
# Nearest to however: paces,  shaolin,  loomis,  kessler,  rupee,  necklace,  gwen,  interval,
# Nearest to are: cdma,  announcers,  predictions,  smiley,  organist,  ix,  devout,  drab,
# Nearest to system: fulk,  diamond,  clipped,  negus,  ess,  aldrich,  swnt,  fabrics,
# Nearest to over: mattingly,  sea,  rockstar,  kournikova,  scant,  sistine,  hp,  allow,
# Nearest to eight: kicker,  brabant,  babes,  gd,  galactica,  traumas,  bremerhaven,  hbk,
# Average loss at step  2000 :  43.82895186042786
# Nearest to was: secure,  alberoni,  doctrine,  cady,  claus,  plume,  subsumed,  intact,
# Nearest to one: in,  marksman,  elca,  of,  mur,  and,  the,  to,
# Nearest to in: of,  to,  one,  and,  the,  UNK,  on,  s,
# Nearest to th: kuwaiti,  lir,  enciphered,  blind,  manfred,  dahmer,  courtyards,  limb,
# Nearest to would: absorbed,  stamping,  consular,  focussing,  segments,  cs,  tank,  talk,
# Nearest to been: ionic,  recovered,  nic,  earliest,  zseries,  freehold,  jovian,  dysfunctional,
# Nearest to zero: wai,  help,  crafty,  shoulders,  residing,  multiplying,  eberhard,  qualities,
# Nearest to who: detonator,  approximating,  misery,  waff,  azteca,  cornwall,  lintel,  airplanes,
# Nearest to UNK: the,  in,  of,  nicknamed,  a,  drummers,  madras,  one,
# Nearest to an: elisha,  portrayed,  coens,  tolerable,  manipulation,  feature,  etienne,  lancastrian,
# Nearest to known: schwerin,  sha,  resumed,  shahada,  vs,  golf,  inflating,  keegan,
# Nearest to however: shaolin,  paces,  necklace,  loomis,  gwen,  falun,  kessler,  appleton,
# Nearest to are: ix,  announcers,  cdma,  webster,  predictions,  subsumed,  ponies,  bose,
# Nearest to system: fulk,  diamond,  clipped,  negus,  ess,  aldrich,  swnt,  waring,
# Nearest to over: mattingly,  acted,  scant,  kournikova,  nicola,  justice,  resolve,  sea,
# Nearest to eight: kicker,  gd,  brabant,  which,  biosphere,  vastly,  babes,  ulema,
# Average loss at step  3000 :  32.04945830440521
# Nearest to was: secure,  alberoni,  of,  is,  and,  cady,  asterism,  doctrine,
# Nearest to one: of,  in,  and,  zero,  UNK,  the,  to,  tartaric,
# Nearest to in: of,  and,  to,  UNK,  one,  the,  nine,  on,
# Nearest to th: kuwaiti,  esque,  blind,  brendan,  lir,  toussaint,  manfred,  guardia,
# Nearest to would: absorbed,  stamping,  focussing,  tank,  consular,  cs,  talk,  segments,
# Nearest to been: ionic,  recovered,  earliest,  aclu,  zseries,  nic,  freehold,  dysfunctional,
# Nearest to zero: stirred,  belatedly,  pharmacology,  compulsory,  hopped,  residing,  wealthy,  wai,
# Nearest to who: misery,  approximating,  detonator,  waff,  lintel,  airplanes,  azteca,  nand,
# Nearest to UNK: in,  of,  the,  a,  one,  to,  nicknamed,  and,
# Nearest to an: one,  and,  coens,  elisha,  portrayed,  manipulation,  canc,  tolerable,
# Nearest to known: schwerin,  shahada,  sha,  resumed,  vs,  golf,  keegan,  inflating,
# Nearest to however: shaolin,  paces,  gwen,  necklace,  falun,  bisexual,  appleton,  groupings,
# Nearest to are: and,  webster,  ix,  predictions,  announcers,  was,  cdma,  universally,
# Nearest to system: diamond,  ess,  fulk,  negus,  clipped,  thoughts,  waring,  fabrics,
# Nearest to over: mattingly,  nicola,  scant,  acted,  ventral,  justice,  verbally,  sea,
# Nearest to eight: which,  gd,  kicker,  vastly,  babes,  brabant,  tahitian,  qui,
# Average loss at step  4000 :  24.871690135002137
# Nearest to was: is,  in,  and,  secure,  alberoni,  a,  are,  of,
# Nearest to one: zero,  and,  UNK,  nine,  in,  of,  the,  two,
# Nearest to in: of,  and,  to,  UNK,  one,  nine,  the,  two,
# Nearest to th: esque,  kuwaiti,  brendan,  lir,  blind,  toussaint,  manfred,  guardia,
# Nearest to would: absorbed,  stamping,  focussing,  tank,  consular,  that,  talk,  cs,
# Nearest to been: ionic,  recovered,  aclu,  earliest,  zseries,  dysfunctional,  freehold,  nic,
# Nearest to zero: one,  nine,  and,  of,  in,  UNK,  methamphetamine,  to,
# Nearest to who: misery,  approximating,  waff,  detonator,  lintel,  nand,  airplanes,  evangelists,
# Nearest to UNK: one,  the,  in,  of,  and,  a,  to,  two,
# Nearest to an: one,  coens,  and,  elisha,  manipulation,  canc,  portrayed,  tolerable,
# Nearest to known: schwerin,  shahada,  sha,  vs,  resumed,  adair,  keegan,  golf,
# Nearest to however: shaolin,  paces,  gwen,  bisexual,  braves,  appleton,  fundamental,  governments,
# Nearest to are: was,  of,  and,  zero,  webster,  ix,  predictions,  universally,
# Nearest to system: diamond,  ess,  fulk,  thoughts,  clipped,  negus,  fabrics,  descriptions,
# Nearest to over: mattingly,  nicola,  ventral,  scant,  acted,  sea,  justice,  artistic,
# Nearest to eight: which,  gd,  kicker,  vastly,  babes,  darwinian,  suffices,  vulcan,
# Average loss at step  5000 :  20.16334005689621
# Nearest to was: is,  in,  and,  alberoni,  secure,  are,  from,  UNK,
# Nearest to one: UNK,  zero,  and,  two,  the,  of,  nine,  in,
# Nearest to in: and,  of,  to,  UNK,  for,  is,  nine,  the,
# Nearest to th: esque,  kuwaiti,  brendan,  blind,  lir,  manfred,  toussaint,  guardia,
# Nearest to would: absorbed,  stamping,  tank,  focussing,  that,  consular,  talk,  cs,
# Nearest to been: ionic,  earliest,  recovered,  aclu,  zseries,  dysfunctional,  nic,  contributed,
# Nearest to zero: one,  nine,  and,  of,  UNK,  methamphetamine,  in,  the,
# Nearest to who: misery,  approximating,  waff,  detonator,  this,  lintel,  and,  nand,
# Nearest to UNK: and,  the,  one,  in,  of,  two,  to,  a,
# Nearest to an: one,  coens,  portrayed,  canc,  manipulation,  tolerable,  elisha,  sheave,
# Nearest to known: schwerin,  shahada,  adair,  vs,  sha,  keegan,  inflating,  resumed,
# Nearest to however: shaolin,  and,  of,  a,  gwen,  paces,  bisexual,  fundamental,
# Nearest to are: and,  was,  of,  webster,  ix,  zero,  predictions,  universally,
# Nearest to system: diamond,  ess,  thoughts,  fulk,  metropolis,  illicit,  epimenides,  fabrics,
# Nearest to over: mattingly,  ventral,  nicola,  scant,  acted,  artistic,  sea,  justice,
# Nearest to eight: which,  and,  gd,  kicker,  two,  vastly,  babes,  suffices,
# Average loss at step  6000 :  17.071460297584533
# Nearest to was: is,  in,  and,  UNK,  alberoni,  secure,  are,  a,
# Nearest to one: UNK,  two,  nine,  and,  zero,  the,  in,  a,
# Nearest to in: and,  of,  to,  UNK,  for,  is,  two,  the,
# Nearest to th: esque,  kuwaiti,  brendan,  blind,  lir,  manfred,  toussaint,  satirizes,
# Nearest to would: absorbed,  stamping,  tank,  focussing,  that,  consular,  talk,  cs,
# Nearest to been: ionic,  earliest,  recovered,  aclu,  dysfunctional,  zseries,  contributed,  freehold,
# Nearest to zero: one,  and,  nine,  in,  of,  UNK,  canis,  two,
# Nearest to who: approximating,  this,  waff,  misery,  detonator,  lintel,  and,  zero,
# Nearest to UNK: and,  in,  the,  one,  of,  two,  a,  to,
# Nearest to an: UNK,  one,  the,  coens,  and,  canc,  portrayed,  manipulation,
# Nearest to known: schwerin,  adair,  shahada,  vs,  keegan,  habit,  sha,  inflating,
# Nearest to however: and,  a,  to,  shaolin,  of,  in,  the,  gwen,
# Nearest to are: and,  was,  of,  webster,  ix,  zero,  predictions,  or,
# Nearest to system: diamond,  thoughts,  ess,  fulk,  illicit,  epimenides,  metropolis,  fabrics,
# Nearest to over: mattingly,  ventral,  nicola,  scant,  acted,  artistic,  sea,  ready,
# Nearest to eight: which,  and,  mimeograph,  kicker,  mondial,  gd,  suffices,  minden,
# Average loss at step  7000 :  14.371542641878127
# Nearest to was: is,  in,  and,  are,  alberoni,  a,  UNK,  secure,
# Nearest to one: and,  UNK,  two,  the,  nine,  zero,  a,  of,
# Nearest to in: of,  and,  to,  UNK,  is,  for,  as,  by,
# Nearest to th: esque,  brendan,  kuwaiti,  blind,  lir,  satirizes,  manfred,  toussaint,
# Nearest to would: absorbed,  that,  stamping,  focussing,  tank,  nine,  talk,  consular,
# Nearest to been: ionic,  earliest,  zseries,  recovered,  aclu,  dysfunctional,  contributed,  an,
# Nearest to zero: nine,  one,  and,  in,  of,  two,  UNK,  three,
# Nearest to who: approximating,  waff,  this,  misery,  one,  zero,  detonator,  lintel,
# Nearest to UNK: and,  in,  one,  the,  of,  a,  two,  to,
# Nearest to an: one,  coens,  UNK,  the,  canc,  manipulation,  portrayed,  sheave,
# Nearest to known: schwerin,  adair,  shahada,  vs,  keegan,  habit,  inflating,  rama,
# Nearest to however: and,  a,  shaolin,  to,  the,  in,  of,  appleton,
# Nearest to are: and,  was,  of,  or,  zero,  is,  ix,  webster,
# Nearest to system: fulk,  thoughts,  ess,  diamond,  illicit,  epimenides,  ashoka,  metropolis,
# Nearest to over: mattingly,  ventral,  scant,  nicola,  acted,  artistic,  UNK,  sea,
# Nearest to eight: and,  vastly,  mondial,  mimeograph,  buson,  two,  which,  bremerhaven,
# Average loss at step  8000 :  12.461852853298188
# Nearest to was: is,  in,  and,  are,  UNK,  alberoni,  to,  a,
# Nearest to one: two,  nine,  and,  zero,  UNK,  the,  a,  four,
# Nearest to in: and,  of,  to,  for,  UNK,  is,  by,  on,
# Nearest to th: esque,  brendan,  kuwaiti,  blind,  lir,  satirizes,  manfred,  toussaint,
# Nearest to would: that,  absorbed,  stamping,  focussing,  tank,  talk,  were,  consular,
# Nearest to been: ionic,  recovered,  zseries,  earliest,  dysfunctional,  contributed,  an,  aclu,
# Nearest to zero: nine,  one,  and,  two,  in,  of,  eight,  five,
# Nearest to who: approximating,  this,  waff,  zero,  and,  misery,  one,  detonator,
# Nearest to UNK: and,  in,  a,  the,  one,  two,  of,  to,
# Nearest to an: the,  one,  UNK,  coens,  manipulation,  canc,  and,  sheave,
# Nearest to known: schwerin,  adair,  shahada,  keegan,  vs,  habit,  inflating,  rama,
# Nearest to however: and,  of,  a,  in,  shaolin,  the,  to,  appleton,
# Nearest to are: and,  was,  of,  is,  or,  in,  zero,  webster,
# Nearest to system: UNK,  thoughts,  fulk,  epimenides,  ess,  illicit,  diamond,  ashoka,
# Nearest to over: UNK,  ventral,  mattingly,  scant,  nicola,  acted,  modern,  artistic,
# Nearest to eight: nine,  zero,  two,  one,  and,  five,  mimeograph,  mondial,
# Average loss at step  9000 :  10.476629178285599
# Nearest to was: is,  and,  in,  are,  UNK,  to,  by,  a,
# Nearest to one: two,  nine,  zero,  and,  UNK,  the,  a,  four,
# Nearest to in: and,  of,  to,  for,  by,  UNK,  two,  is,
# Nearest to th: esque,  brendan,  kuwaiti,  blind,  satirizes,  ventral,  complicated,  lir,
# Nearest to would: that,  absorbed,  focussing,  stamping,  tank,  were,  talk,  those,
# Nearest to been: and,  ionic,  an,  zseries,  recovered,  earliest,  contributed,  dysfunctional,
# Nearest to zero: nine,  one,  and,  two,  eight,  in,  of,  three,
# Nearest to who: and,  this,  approximating,  zero,  also,  waff,  misery,  detonator,
# Nearest to UNK: and,  one,  the,  in,  a,  two,  of,  zero,
# Nearest to an: the,  one,  UNK,  and,  coens,  canc,  manipulation,  a,
# Nearest to known: schwerin,  adair,  keegan,  shahada,  habit,  rama,  vs,  xm,
# Nearest to however: and,  in,  a,  of,  shaolin,  the,  to,  appleton,
# Nearest to are: and,  was,  is,  in,  or,  of,  zero,  a,
# Nearest to system: UNK,  four,  fulk,  epimenides,  thoughts,  ashoka,  illicit,  five,
# Nearest to over: UNK,  ventral,  mattingly,  scant,  modern,  nicola,  acted,  to,
# Nearest to eight: nine,  zero,  one,  two,  and,  five,  in,  seven,
# Average loss at step  10000 :  9.817836978554725
# Nearest to was: is,  and,  in,  are,  UNK,  by,  from,  three,
# Nearest to one: two,  nine,  and,  zero,  UNK,  the,  eight,  a,
# Nearest to in: and,  of,  for,  to,  by,  nine,  is,  UNK,
# Nearest to th: esque,  brendan,  complicated,  ventral,  kuwaiti,  blind,  satirizes,  ishaq,
# Nearest to would: that,  absorbed,  focussing,  were,  stamping,  tank,  to,  those,
# Nearest to been: ionic,  an,  and,  zseries,  recovered,  earliest,  contributed,  dysfunctional,
# Nearest to zero: nine,  two,  one,  eight,  and,  five,  three,  in,
# Nearest to who: and,  approximating,  this,  zero,  also,  waff,  misery,  detonator,
# Nearest to UNK: and,  one,  the,  in,  two,  a,  nine,  zero,
# Nearest to an: the,  one,  and,  UNK,  coens,  manipulation,  canc,  two,
# Nearest to known: schwerin,  adair,  keegan,  shahada,  inflating,  habit,  rama,  vs,
# Nearest to however: and,  a,  of,  in,  shaolin,  appleton,  for,  fundamental,
# Nearest to are: and,  was,  is,  in,  or,  of,  ix,  nine,
# Nearest to system: four,  fulk,  epimenides,  thoughts,  number,  ashoka,  UNK,  illicit,
# Nearest to over: UNK,  ventral,  mattingly,  scant,  nicola,  modern,  acted,  berklee,
# Nearest to eight: nine,  zero,  one,  two,  and,  five,  in,  seven,
# Average loss at step  11000 :  9.063006248950959
# Nearest to was: is,  and,  in,  are,  UNK,  by,  three,  a,
# Nearest to one: two,  nine,  zero,  and,  the,  UNK,  eight,  four,
# Nearest to in: and,  of,  for,  to,  by,  on,  nine,  from,
# Nearest to th: esque,  brendan,  ventral,  complicated,  kuwaiti,  blind,  eclac,  cultivation,
# Nearest to would: a,  that,  were,  focussing,  absorbed,  stamping,  tank,  to,
# Nearest to been: ionic,  an,  zseries,  recovered,  contributed,  dysfunctional,  is,  and,
# Nearest to zero: nine,  one,  two,  eight,  and,  five,  three,  seven,
# Nearest to who: and,  this,  zero,  also,  approximating,  waff,  misery,  that,
# Nearest to UNK: and,  one,  a,  in,  the,  two,  zero,  was,
# Nearest to an: the,  one,  and,  UNK,  a,  two,  coens,  canc,
# Nearest to known: schwerin,  adair,  a,  UNK,  keegan,  inflating,  shahada,  sheriff,
# Nearest to however: and,  a,  in,  of,  shaolin,  to,  for,  appleton,
# Nearest to are: and,  was,  is,  or,  in,  of,  a,  nine,
# Nearest to system: four,  fulk,  epimenides,  number,  thoughts,  ashoka,  illicit,  metropolis,
# Nearest to over: UNK,  ventral,  mattingly,  modern,  scant,  nicola,  acted,  berklee,
# Nearest to eight: nine,  zero,  one,  two,  five,  a,  seven,  and,
# Average loss at step  12000 :  8.42263815999031
# Nearest to was: is,  and,  in,  are,  three,  by,  UNK,  nine,
# Nearest to one: two,  nine,  zero,  eight,  and,  UNK,  the,  three,
# Nearest to in: and,  of,  for,  by,  to,  nine,  on,  three,
# Nearest to th: esque,  ventral,  brendan,  complicated,  kuwaiti,  eclac,  cultivation,  blind,
# Nearest to would: that,  were,  a,  those,  is,  to,  focussing,  stamping,
# Nearest to been: ionic,  an,  zseries,  recovered,  contributed,  is,  dysfunctional,  earliest,
# Nearest to zero: nine,  two,  one,  eight,  three,  five,  and,  six,
# Nearest to who: and,  this,  also,  approximating,  that,  misery,  waff,  zero,
# Nearest to UNK: and,  one,  a,  the,  two,  in,  nine,  three,
# Nearest to an: the,  one,  and,  UNK,  a,  it,  this,  canc,
# Nearest to known: schwerin,  a,  adair,  keegan,  inflating,  xm,  sheriff,  wedgwood,
# Nearest to however: and,  in,  of,  to,  for,  shaolin,  a,  the,
# Nearest to are: is,  was,  and,  or,  in,  nine,  by,  of,
# Nearest to system: four,  fulk,  epimenides,  ashoka,  illicit,  thoughts,  number,  metropolis,
# Nearest to over: UNK,  ventral,  modern,  mattingly,  scant,  nicola,  acted,  became,
# Nearest to eight: nine,  zero,  one,  two,  five,  three,  seven,  and,
# Average loss at step  13000 :  7.4934876017570495
# Nearest to was: is,  and,  in,  are,  by,  three,  UNK,  two,
# Nearest to one: two,  nine,  zero,  eight,  and,  three,  UNK,  the,
# Nearest to in: and,  of,  for,  by,  to,  on,  from,  is,
# Nearest to th: esque,  ventral,  two,  brendan,  complicated,  kuwaiti,  eclac,  cultivation,
# Nearest to would: that,  were,  is,  those,  to,  focussing,  a,  stamping,
# Nearest to been: ionic,  zseries,  an,  recovered,  was,  contributed,  dysfunctional,  earliest,
# Nearest to zero: nine,  two,  and,  one,  eight,  three,  five,  four,
# Nearest to who: and,  also,  this,  approximating,  that,  misery,  waff,  not,
# Nearest to UNK: and,  one,  two,  a,  the,  in,  three,  is,
# Nearest to an: the,  UNK,  one,  and,  a,  it,  two,  canc,
# Nearest to known: schwerin,  a,  adair,  UNK,  keegan,  xm,  inflating,  wedgwood,
# Nearest to however: and,  in,  of,  for,  to,  a,  shaolin,  the,
# Nearest to are: and,  is,  was,  or,  in,  nine,  by,  of,
# Nearest to system: UNK,  four,  two,  fulk,  number,  epimenides,  ashoka,  and,
# Nearest to over: UNK,  ventral,  modern,  mattingly,  scant,  nicola,  acted,  became,
# Nearest to eight: nine,  zero,  two,  one,  three,  five,  seven,  and,
# Average loss at step  14000 :  7.136808641076088
# Nearest to was: is,  and,  by,  are,  in,  three,  for,  UNK,
# Nearest to one: two,  nine,  UNK,  eight,  three,  zero,  the,  four,
# Nearest to in: and,  of,  for,  by,  on,  to,  from,  nine,
# Nearest to th: two,  ventral,  esque,  complicated,  brendan,  cultivation,  eclac,  kuwaiti,
# Nearest to would: that,  to,  is,  were,  those,  focussing,  a,  stamping,
# Nearest to been: ionic,  was,  an,  zseries,  recovered,  contributed,  dysfunctional,  earliest,
# Nearest to zero: nine,  two,  three,  eight,  one,  five,  and,  four,
# Nearest to who: and,  also,  this,  that,  approximating,  not,  though,  misery,
# Nearest to UNK: and,  one,  two,  the,  a,  in,  three,  nine,
# Nearest to an: the,  UNK,  one,  a,  it,  and,  manipulation,  two,
# Nearest to known: a,  schwerin,  adair,  UNK,  keegan,  xm,  wedgwood,  inflating,
# Nearest to however: and,  in,  for,  to,  of,  a,  shaolin,  is,
# Nearest to are: is,  was,  and,  or,  in,  by,  as,  were,
# Nearest to system: UNK,  four,  and,  fulk,  number,  each,  two,  a,
# Nearest to over: UNK,  ventral,  modern,  mattingly,  and,  scant,  nicola,  became,
# Nearest to eight: nine,  one,  zero,  two,  three,  five,  seven,  four,
# Average loss at step  15000 :  6.8827629956007
# Nearest to was: is,  and,  are,  in,  by,  three,  as,  for,
# Nearest to one: two,  nine,  eight,  zero,  three,  UNK,  four,  five,
# Nearest to in: and,  of,  for,  by,  on,  from,  as,  UNK,
# Nearest to th: two,  ventral,  esque,  complicated,  brendan,  eclac,  cultivation,  ishaq,
# Nearest to would: that,  to,  were,  is,  those,  a,  focussing,  stamping,
# Nearest to been: was,  an,  ionic,  zseries,  recovered,  is,  contributed,  by,
# Nearest to zero: two,  nine,  three,  eight,  one,  five,  four,  six,
# Nearest to who: and,  this,  also,  that,  not,  approximating,  though,  among,
# Nearest to UNK: and,  one,  two,  in,  a,  the,  three,  eight,
# Nearest to an: the,  UNK,  one,  a,  and,  it,  sheave,  canc,
# Nearest to known: a,  UNK,  schwerin,  adair,  keegan,  every,  xm,  inflating,
# Nearest to however: and,  in,  for,  a,  is,  shaolin,  of,  to,
# Nearest to are: is,  was,  and,  or,  in,  by,  as,  were,
# Nearest to system: and,  UNK,  four,  number,  fulk,  each,  epimenides,  a,
# Nearest to over: UNK,  ventral,  modern,  sea,  mattingly,  became,  scant,  nicola,
# Nearest to eight: nine,  zero,  one,  two,  five,  three,  seven,  four,
# Average loss at step  16000 :  6.3404624481201175
# Nearest to was: is,  by,  and,  are,  in,  for,  as,  three,
# Nearest to one: two,  three,  nine,  eight,  zero,  five,  four,  UNK,
# Nearest to in: and,  of,  for,  by,  from,  on,  as,  with,
# Nearest to th: two,  ventral,  esque,  cultivation,  complicated,  brendan,  eclac,  ishaq,
# Nearest to would: that,  to,  were,  those,  is,  stamping,  focussing,  because,
# Nearest to been: was,  an,  ionic,  zseries,  by,  recovered,  contributed,  dysfunctional,
# Nearest to zero: nine,  two,  eight,  three,  one,  five,  four,  and,
# Nearest to who: and,  that,  also,  this,  not,  UNK,  approximating,  though,
# Nearest to UNK: and,  one,  in,  two,  a,  the,  by,  three,
# Nearest to an: the,  one,  a,  UNK,  it,  and,  two,  which,
# Nearest to known: a,  schwerin,  UNK,  adair,  keegan,  xm,  inflating,  sigmund,
# Nearest to however: and,  in,  for,  to,  a,  shaolin,  is,  four,
# Nearest to are: is,  was,  and,  or,  UNK,  in,  by,  were,
# Nearest to system: UNK,  four,  and,  a,  number,  fulk,  five,  each,
# Nearest to over: UNK,  ventral,  modern,  sea,  mattingly,  became,  nicola,  berklee,
# Nearest to eight: nine,  zero,  one,  two,  three,  five,  seven,  four,
# Average loss at step  17000 :  6.205697835445404
# Nearest to was: is,  by,  and,  are,  in,  for,  as,  three,
# Nearest to one: two,  nine,  three,  eight,  four,  five,  zero,  the,
# Nearest to in: and,  of,  for,  by,  on,  from,  with,  nine,
# Nearest to th: two,  ventral,  cultivation,  esque,  complicated,  one,  eclac,  ishaq,
# Nearest to would: that,  to,  were,  is,  those,  because,  stamping,  focussing,
# Nearest to been: was,  an,  by,  ionic,  zseries,  recovered,  contributed,  dysfunctional,
# Nearest to zero: three,  nine,  two,  eight,  five,  four,  one,  and,
# Nearest to who: also,  that,  this,  and,  not,  approximating,  though,  UNK,
# Nearest to UNK: and,  one,  two,  the,  a,  in,  three,  by,
# Nearest to an: the,  one,  UNK,  a,  it,  and,  his,  which,
# Nearest to known: a,  schwerin,  adair,  keegan,  sigmund,  xm,  inflating,  every,
# Nearest to however: and,  in,  for,  a,  is,  shaolin,  to,  of,
# Nearest to are: is,  was,  and,  in,  or,  UNK,  by,  were,
# Nearest to system: four,  and,  UNK,  number,  fulk,  epimenides,  five,  a,
# Nearest to over: UNK,  sea,  modern,  ventral,  became,  mattingly,  berklee,  nicola,
# Nearest to eight: nine,  zero,  one,  two,  three,  five,  seven,  four,
# Average loss at step  18000 :  5.490272775173187
# Nearest to was: is,  by,  are,  in,  and,  as,  for,  three,
# Nearest to one: two,  eight,  four,  three,  nine,  five,  the,  zero,
# Nearest to in: and,  for,  of,  by,  on,  as,  from,  with,
# Nearest to th: two,  ventral,  cultivation,  one,  esque,  complicated,  eclac,  ishaq,
# Nearest to would: that,  to,  were,  is,  those,  because,  stamping,  focussing,
# Nearest to been: was,  an,  by,  ionic,  zseries,  recovered,  contributed,  is,
# Nearest to zero: two,  three,  eight,  nine,  four,  six,  five,  seven,
# Nearest to who: also,  that,  this,  and,  not,  approximating,  though,  as,
# Nearest to UNK: and,  two,  one,  in,  three,  zero,  a,  by,
# Nearest to an: the,  a,  one,  it,  UNK,  and,  which,  his,
# Nearest to known: a,  schwerin,  adair,  keegan,  sigmund,  xm,  inflating,  wedgwood,
# Nearest to however: and,  in,  for,  shaolin,  of,  four,  is,  a,
# Nearest to are: is,  was,  and,  in,  or,  were,  by,  UNK,
# Nearest to system: and,  four,  fulk,  epimenides,  number,  each,  UNK,  ashoka,
# Nearest to over: UNK,  sea,  ventral,  modern,  mattingly,  and,  zero,  berklee,
# Nearest to eight: nine,  zero,  three,  one,  two,  five,  four,  seven,
# Average loss at step  19000 :  5.4036201118230816
# Nearest to was: is,  by,  are,  in,  and,  as,  for,  has,
# Nearest to one: two,  eight,  four,  three,  zero,  nine,  five,  seven,
# Nearest to in: and,  for,  of,  by,  on,  from,  as,  to,
# Nearest to th: two,  ventral,  four,  one,  cultivation,  complicated,  eight,  esque,
# Nearest to would: that,  to,  were,  is,  those,  was,  because,  stamping,
# Nearest to been: was,  an,  by,  ionic,  is,  zseries,  recovered,  contributed,
# Nearest to zero: three,  two,  eight,  nine,  four,  five,  one,  seven,
# Nearest to who: and,  also,  that,  this,  UNK,  not,  of,  though,
# Nearest to UNK: and,  one,  two,  three,  seven,  a,  zero,  the,
# Nearest to an: the,  a,  it,  one,  UNK,  and,  which,  this,
# Nearest to known: a,  schwerin,  UNK,  adair,  keegan,  xm,  sigmund,  inflating,
# Nearest to however: and,  in,  for,  of,  shaolin,  four,  on,  a,
# Nearest to are: is,  was,  and,  in,  or,  were,  UNK,  by,
# Nearest to system: UNK,  four,  and,  number,  fulk,  epimenides,  each,  postpositions,
# Nearest to over: sea,  UNK,  ventral,  modern,  mattingly,  and,  berklee,  became,
# Nearest to eight: nine,  one,  zero,  three,  two,  five,  four,  seven,
# Average loss at step  20000 :  5.300805303931236
# Nearest to was: is,  by,  are,  in,  and,  as,  has,  three,
# Nearest to one: two,  eight,  four,  three,  zero,  the,  nine,  seven,
# Nearest to in: and,  of,  for,  by,  on,  from,  as,  with,
# Nearest to th: two,  four,  eight,  three,  one,  ventral,  nine,  six,
# Nearest to would: that,  to,  were,  is,  those,  because,  was,  stamping,
# Nearest to been: was,  by,  an,  is,  ionic,  zseries,  recovered,  as,
# Nearest to zero: three,  nine,  two,  five,  eight,  four,  seven,  six,
# Nearest to who: and,  that,  also,  this,  not,  though,  UNK,  approximating,
# Nearest to UNK: and,  one,  two,  three,  a,  the,  which,  or,
# Nearest to an: the,  one,  a,  it,  UNK,  and,  which,  this,
# Nearest to known: a,  schwerin,  adair,  keegan,  xm,  sigmund,  which,  inflating,
# Nearest to however: and,  in,  of,  for,  four,  shaolin,  on,  was,
# Nearest to are: is,  was,  and,  were,  in,  or,  by,  UNK,
# Nearest to system: four,  and,  UNK,  fulk,  epimenides,  number,  a,  postpositions,
# Nearest to over: sea,  UNK,  ventral,  modern,  mattingly,  berklee,  and,  became,
# Nearest to eight: nine,  three,  zero,  one,  two,  four,  five,  seven,
# Average loss at step  21000 :  4.960717757940293
# Nearest to was: is,  by,  are,  in,  and,  has,  as,  s,
# Nearest to one: two,  four,  three,  eight,  five,  zero,  seven,  UNK,
# Nearest to in: and,  of,  for,  from,  by,  on,  with,  nine,
# Nearest to th: two,  four,  three,  six,  ventral,  seven,  eight,  cultivation,
# Nearest to would: that,  to,  were,  is,  those,  was,  because,  are,
# Nearest to been: was,  by,  an,  is,  are,  ionic,  were,  zseries,
# Nearest to zero: nine,  two,  three,  eight,  five,  seven,  four,  six,
# Nearest to who: and,  that,  also,  this,  not,  approximating,  though,  among,
# Nearest to UNK: and,  one,  two,  three,  the,  which,  four,  a,
# Nearest to an: the,  one,  a,  it,  and,  UNK,  which,  his,
# Nearest to known: a,  schwerin,  adair,  UNK,  which,  keegan,  list,  sigmund,
# Nearest to however: and,  in,  four,  for,  of,  shaolin,  one,  on,
# Nearest to are: is,  was,  were,  and,  in,  or,  by,  three,
# Nearest to system: four,  and,  number,  UNK,  fulk,  epimenides,  each,  three,
# Nearest to over: sea,  ventral,  modern,  mattingly,  became,  berklee,  UNK,  acted,
# Nearest to eight: nine,  zero,  three,  two,  five,  seven,  four,  one,
# Average loss at step  22000 :  5.084272901892662
# Nearest to was: is,  by,  are,  in,  as,  has,  and,  s,
# Nearest to one: two,  four,  three,  eight,  five,  six,  seven,  nine,
# Nearest to in: and,  for,  from,  on,  of,  by,  with,  at,
# Nearest to th: two,  four,  three,  six,  ventral,  seven,  eight,  cultivation,
# Nearest to would: that,  were,  is,  to,  those,  was,  because,  are,
# Nearest to been: was,  by,  an,  is,  are,  were,  ionic,  recovered,
# Nearest to zero: three,  five,  nine,  two,  eight,  six,  four,  seven,
# Nearest to who: that,  also,  and,  this,  not,  approximating,  though,  among,
# Nearest to UNK: and,  one,  two,  three,  a,  which,  the,  four,
# Nearest to an: the,  one,  it,  a,  UNK,  and,  which,  his,
# Nearest to known: a,  schwerin,  UNK,  which,  adair,  keegan,  list,  every,
# Nearest to however: and,  in,  was,  four,  on,  is,  shaolin,  for,
# Nearest to are: is,  was,  were,  and,  in,  or,  by,  as,
# Nearest to system: four,  and,  number,  a,  UNK,  each,  fulk,  epimenides,
# Nearest to over: sea,  ventral,  modern,  UNK,  mattingly,  became,  berklee,  acted,
# Nearest to eight: nine,  three,  zero,  five,  four,  seven,  two,  six,
# Average loss at step  23000 :  4.754444237589836
# Nearest to was: is,  by,  are,  and,  in,  as,  has,  s,
# Nearest to one: two,  four,  three,  UNK,  five,  six,  seven,  eight,
# Nearest to in: and,  of,  for,  on,  from,  by,  at,  with,
# Nearest to th: two,  four,  three,  six,  one,  seven,  ventral,  eight,
# Nearest to would: to,  that,  is,  were,  those,  are,  was,  because,
# Nearest to been: was,  by,  is,  are,  an,  ionic,  strong,  recovered,
# Nearest to zero: three,  two,  five,  eight,  four,  six,  nine,  seven,
# Nearest to who: that,  also,  and,  this,  not,  among,  though,  approximating,
# Nearest to UNK: one,  and,  two,  three,  five,  four,  seven,  which,
# Nearest to an: the,  one,  a,  it,  UNK,  and,  his,  this,
# Nearest to known: a,  schwerin,  UNK,  adair,  which,  keegan,  sigmund,  xm,
# Nearest to however: and,  in,  was,  is,  one,  four,  on,  to,
# Nearest to are: is,  was,  were,  and,  or,  by,  in,  three,
# Nearest to system: and,  four,  a,  number,  UNK,  fulk,  each,  five,
# Nearest to over: sea,  ventral,  UNK,  modern,  mattingly,  became,  berklee,  acted,
# Nearest to eight: nine,  three,  five,  zero,  four,  two,  seven,  six,
# Average loss at step  24000 :  4.643598788499832
# Nearest to was: is,  by,  are,  and,  in,  has,  as,  eight,
# Nearest to one: two,  three,  four,  five,  six,  eight,  seven,  nine,
# Nearest to in: and,  on,  for,  of,  from,  by,  at,  with,
# Nearest to th: two,  four,  one,  six,  three,  seven,  ventral,  eight,
# Nearest to would: to,  is,  that,  were,  those,  was,  are,  because,
# Nearest to been: was,  by,  is,  are,  an,  were,  strong,  and,
# Nearest to zero: three,  eight,  four,  five,  nine,  six,  two,  seven,
# Nearest to who: that,  also,  and,  this,  not,  some,  among,  though,
# Nearest to UNK: and,  one,  two,  three,  which,  four,  five,  that,
# Nearest to an: the,  it,  one,  a,  UNK,  his,  and,  this,
# Nearest to known: a,  schwerin,  UNK,  adair,  which,  keegan,  it,  sigmund,
# Nearest to however: and,  in,  was,  is,  on,  four,  of,  for,
# Nearest to are: is,  was,  were,  and,  or,  by,  in,  nine,
# Nearest to system: and,  UNK,  a,  fulk,  four,  number,  epimenides,  each,
# Nearest to over: sea,  ventral,  modern,  UNK,  became,  mattingly,  berklee,  acted,
# Nearest to eight: nine,  three,  five,  four,  six,  seven,  zero,  two,
# Average loss at step  25000 :  5.097655686855316
# Nearest to was: is,  are,  by,  has,  in,  as,  and,  were,
# Nearest to one: two,  four,  five,  three,  eight,  six,  seven,  nine,
# Nearest to in: and,  for,  from,  on,  of,  at,  by,  nine,
# Nearest to th: two,  four,  one,  six,  seven,  three,  eight,  ventral,
# Nearest to would: to,  is,  were,  that,  are,  was,  can,  those,
# Nearest to been: was,  by,  is,  are,  an,  were,  strong,  to,
# Nearest to zero: three,  eight,  five,  two,  nine,  four,  six,  seven,
# Nearest to who: that,  also,  and,  this,  not,  among,  which,  some,
# Nearest to UNK: automator,  powdered,  jumblatt,  kaifu,  coating,  invertebrate,  karo,  vater,
# Nearest to an: the,  it,  one,  a,  his,  this,  which,  and,
# Nearest to known: a,  schwerin,  which,  adair,  keegan,  it,  xm,  sigmund,
# Nearest to however: and,  in,  was,  is,  four,  on,  to,  for,
# Nearest to are: is,  was,  were,  and,  or,  by,  in,  for,
# Nearest to system: and,  four,  each,  number,  this,  a,  epimenides,  fulk,
# Nearest to over: sea,  ventral,  modern,  mattingly,  became,  berklee,  acted,  nicola,
# Nearest to eight: nine,  five,  three,  four,  six,  zero,  seven,  two,
# Average loss at step  26000 :  4.558131383895874
# Nearest to was: is,  are,  by,  and,  has,  as,  in,  UNK,
# Nearest to one: two,  four,  three,  five,  eight,  seven,  six,  nine,
# Nearest to in: and,  for,  of,  from,  on,  at,  by,  with,
# Nearest to th: two,  four,  one,  six,  seven,  three,  eight,  ventral,
# Nearest to would: to,  is,  were,  that,  was,  can,  are,  those,
# Nearest to been: was,  by,  is,  are,  were,  an,  strong,  to,
# Nearest to zero: three,  four,  eight,  two,  six,  five,  nine,  seven,
# Nearest to who: that,  also,  and,  this,  not,  which,  among,  though,
# Nearest to UNK: two,  and,  three,  six,  one,  four,  seven,  eight,
# Nearest to an: the,  it,  one,  a,  his,  which,  this,  UNK,
# Nearest to known: a,  UNK,  schwerin,  which,  it,  keegan,  adair,  list,
# Nearest to however: and,  in,  was,  is,  four,  for,  on,  UNK,
# Nearest to are: is,  was,  were,  and,  or,  by,  in,  for,
# Nearest to system: four,  and,  a,  this,  each,  number,  fulk,  epimenides,
# Nearest to over: sea,  ventral,  modern,  became,  and,  mattingly,  berklee,  UNK,
# Nearest to eight: nine,  four,  three,  seven,  zero,  five,  six,  two,
# Average loss at step  27000 :  4.555128597974777
# Nearest to was: is,  by,  are,  and,  has,  in,  as,  were,
# Nearest to one: two,  four,  three,  five,  eight,  seven,  six,  nine,
# Nearest to in: and,  for,  from,  of,  on,  by,  at,  with,
# Nearest to th: two,  one,  four,  three,  six,  seven,  eight,  zero,
# Nearest to would: to,  is,  were,  that,  was,  can,  are,  may,
# Nearest to been: was,  by,  are,  were,  is,  an,  to,  strong,
# Nearest to zero: three,  four,  two,  eight,  five,  six,  nine,  seven,
# Nearest to who: that,  also,  and,  this,  not,  which,  among,  two,
# Nearest to UNK: and,  two,  three,  six,  four,  one,  or,  five,
# Nearest to an: the,  it,  a,  one,  this,  his,  UNK,  which,
# Nearest to known: a,  UNK,  schwerin,  which,  keegan,  adair,  it,  list,
# Nearest to however: and,  in,  four,  is,  was,  for,  on,  shaolin,
# Nearest to are: is,  were,  was,  and,  or,  by,  in,  but,
# Nearest to system: and,  a,  four,  this,  number,  each,  fulk,  epimenides,
# Nearest to over: sea,  ventral,  modern,  became,  UNK,  zero,  mattingly,  three,
# Nearest to eight: nine,  four,  three,  five,  seven,  six,  zero,  two,
# Average loss at step  28000 :  4.087826742649078
# Nearest to was: is,  by,  are,  and,  has,  in,  as,  were,
# Nearest to one: two,  four,  three,  five,  eight,  seven,  six,  zero,
# Nearest to in: and,  for,  from,  of,  on,  by,  at,  with,
# Nearest to th: two,  four,  one,  six,  three,  eight,  seven,  ventral,
# Nearest to would: to,  were,  is,  can,  was,  that,  may,  are,
# Nearest to been: was,  by,  are,  is,  were,  a,  an,  strong,
# Nearest to zero: four,  eight,  three,  five,  six,  two,  seven,  nine,
# Nearest to who: that,  also,  and,  not,  this,  which,  among,  some,
# Nearest to UNK: and,  two,  one,  four,  three,  six,  or,  seven,
# Nearest to an: the,  it,  a,  one,  UNK,  this,  his,  which,
# Nearest to known: a,  UNK,  schwerin,  it,  which,  keegan,  adair,  list,
# Nearest to however: in,  and,  was,  is,  four,  the,  on,  for,
# Nearest to are: is,  were,  was,  and,  or,  in,  by,  have,
# Nearest to system: and,  a,  four,  number,  each,  this,  fulk,  epimenides,
# Nearest to over: sea,  ventral,  modern,  became,  and,  UNK,  berklee,  mattingly,
# Nearest to eight: nine,  four,  five,  six,  three,  seven,  zero,  two,
# Average loss at step  29000 :  4.163070261597634
# Nearest to was: is,  by,  are,  and,  has,  were,  as,  in,
# Nearest to one: two,  four,  three,  five,  eight,  six,  seven,  zero,
# Nearest to in: and,  for,  from,  of,  on,  by,  at,  with,
# Nearest to th: two,  one,  four,  three,  six,  eight,  seven,  five,
# Nearest to would: to,  were,  can,  is,  and,  was,  are,  may,
# Nearest to been: was,  by,  are,  were,  is,  strong,  an,  to,
# Nearest to zero: four,  three,  eight,  five,  six,  two,  seven,  nine,
# Nearest to who: that,  also,  and,  not,  this,  which,  two,  among,
# Nearest to UNK: and,  two,  one,  four,  three,  five,  or,  six,
# Nearest to an: the,  it,  UNK,  one,  a,  this,  his,  which,
# Nearest to known: a,  UNK,  schwerin,  it,  which,  keegan,  adair,  list,
# Nearest to however: in,  and,  was,  is,  four,  one,  on,  for,
# Nearest to are: is,  were,  was,  and,  or,  in,  by,  but,
# Nearest to system: and,  four,  a,  five,  this,  each,  number,  fulk,
# Nearest to over: sea,  ventral,  modern,  three,  and,  became,  UNK,  berklee,
# Nearest to eight: nine,  four,  five,  six,  seven,  three,  zero,  one,
# Average loss at step  30000 :  4.347256691217423
# Nearest to was: is,  by,  are,  and,  has,  were,  as,  in,
# Nearest to one: two,  four,  eight,  three,  seven,  five,  six,  nine,
# Nearest to in: and,  for,  from,  of,  on,  at,  by,  with,
# Nearest to th: two,  one,  four,  three,  six,  eight,  seven,  five,
# Nearest to would: to,  can,  were,  and,  was,  is,  may,  are,
# Nearest to been: was,  by,  are,  were,  is,  strong,  and,  an,
# Nearest to zero: eight,  three,  four,  five,  six,  seven,  two,  nine,
# Nearest to who: that,  also,  and,  not,  this,  which,  two,  among,
# Nearest to UNK: and,  one,  two,  four,  three,  five,  six,  seven,
# Nearest to an: the,  it,  this,  his,  a,  one,  UNK,  and,
# Nearest to known: a,  schwerin,  UNK,  it,  which,  keegan,  adair,  one,
# Nearest to however: and,  in,  was,  is,  four,  on,  six,  for,
# Nearest to are: is,  were,  was,  and,  or,  have,  by,  in,
# Nearest to system: and,  four,  this,  each,  a,  number,  fulk,  five,
# Nearest to over: sea,  and,  ventral,  modern,  zero,  three,  became,  UNK,
# Nearest to eight: four,  nine,  five,  seven,  six,  three,  zero,  two,
# Average loss at step  31000 :  3.95576704287529
# Nearest to was: is,  by,  are,  has,  were,  as,  and,  eight,
# Nearest to one: two,  four,  six,  three,  seven,  eight,  five,  zero,
# Nearest to in: and,  from,  for,  on,  at,  of,  nine,  by,
# Nearest to th: one,  two,  four,  six,  three,  eight,  seven,  five,
# Nearest to would: to,  can,  were,  is,  may,  was,  are,  that,
# Nearest to been: was,  by,  are,  were,  is,  strong,  become,  as,
# Nearest to zero: eight,  three,  four,  five,  six,  seven,  two,  nine,
# Nearest to who: that,  also,  and,  not,  which,  this,  it,  among,
# Nearest to UNK: and,  four,  two,  three,  one,  five,  six,  seven,
# Nearest to an: the,  it,  one,  this,  his,  a,  UNK,  which,
# Nearest to known: a,  schwerin,  it,  which,  keegan,  adair,  one,  sigmund,
# Nearest to however: in,  and,  is,  was,  four,  six,  on,  eight,
# Nearest to are: were,  is,  was,  and,  have,  or,  but,  eight,
# Nearest to system: four,  and,  each,  this,  number,  a,  five,  fulk,
# Nearest to over: sea,  and,  ventral,  modern,  zero,  UNK,  became,  three,
# Nearest to eight: nine,  seven,  six,  four,  five,  three,  zero,  two,
# Average loss at step  32000 :  4.398048471927643
# Nearest to was: is,  by,  are,  has,  were,  as,  eight,  in,
# Nearest to one: two,  four,  eight,  three,  seven,  six,  five,  nine,
# Nearest to in: and,  from,  at,  for,  of,  on,  by,  with,
# Nearest to th: two,  one,  three,  four,  six,  eight,  seven,  five,
# Nearest to would: can,  to,  were,  may,  was,  are,  is,  that,
# Nearest to been: was,  by,  are,  were,  is,  strong,  become,  as,
# Nearest to zero: eight,  four,  five,  three,  seven,  nine,  six,  two,
# Nearest to who: also,  that,  not,  and,  which,  this,  it,  they,
# Nearest to UNK: and,  one,  three,  two,  four,  six,  seven,  five,
# Nearest to an: the,  it,  this,  his,  one,  a,  UNK,  which,
# Nearest to known: a,  schwerin,  it,  one,  which,  UNK,  keegan,  adair,
# Nearest to however: in,  and,  was,  is,  four,  six,  eight,  for,
# Nearest to are: were,  is,  was,  and,  have,  or,  but,  eight,
# Nearest to system: and,  a,  four,  this,  each,  number,  fulk,  five,
# Nearest to over: sea,  and,  UNK,  ventral,  modern,  became,  three,  berklee,
# Nearest to eight: nine,  four,  seven,  five,  six,  three,  zero,  one,
# Average loss at step  33000 :  4.106950716018677
# Nearest to was: is,  are,  by,  has,  were,  as,  and,  had,
# Nearest to one: two,  eight,  three,  six,  five,  four,  seven,  nine,
# Nearest to in: and,  at,  from,  for,  on,  with,  by,  of,
# Nearest to th: four,  two,  one,  six,  three,  eight,  five,  seven,
# Nearest to would: can,  to,  were,  may,  was,  is,  are,  that,
# Nearest to been: was,  by,  were,  are,  is,  strong,  become,  as,
# Nearest to zero: five,  eight,  six,  three,  four,  seven,  two,  nine,
# Nearest to who: also,  that,  not,  and,  which,  this,  they,  he,
# Nearest to UNK: one,  and,  three,  two,  seven,  four,  five,  or,
# Nearest to an: the,  it,  his,  this,  one,  a,  which,  UNK,
# Nearest to known: a,  schwerin,  it,  which,  keegan,  adair,  one,  sigmund,
# Nearest to however: and,  in,  was,  four,  is,  six,  for,  produced,
# Nearest to are: were,  is,  was,  have,  and,  or,  but,  in,
# Nearest to system: and,  a,  each,  this,  number,  four,  fulk,  five,
# Nearest to over: sea,  ventral,  modern,  UNK,  became,  zero,  and,  berklee,
# Nearest to eight: six,  nine,  five,  seven,  four,  three,  zero,  one,
# Average loss at step  34000 :  4.068005508422852
# Nearest to was: is,  are,  by,  has,  were,  as,  and,  in,
# Nearest to one: two,  three,  eight,  four,  six,  five,  seven,  nine,
# Nearest to in: and,  from,  at,  for,  on,  of,  with,  by,
# Nearest to th: four,  six,  one,  two,  three,  eight,  five,  seven,
# Nearest to would: can,  to,  were,  may,  was,  is,  are,  those,
# Nearest to been: was,  by,  were,  are,  strong,  become,  is,  as,
# Nearest to zero: five,  eight,  six,  four,  three,  seven,  two,  nine,
# Nearest to who: also,  that,  not,  and,  which,  this,  they,  he,
# Nearest to UNK: and,  one,  two,  three,  seven,  four,  five,  six,
# Nearest to an: the,  it,  his,  this,  one,  a,  which,  its,
# Nearest to known: a,  schwerin,  it,  which,  keegan,  adair,  this,  one,
# Nearest to however: in,  and,  was,  is,  four,  six,  for,  on,
# Nearest to are: were,  is,  was,  or,  and,  have,  but,  in,
# Nearest to system: and,  UNK,  a,  this,  each,  number,  fulk,  four,
# Nearest to over: sea,  UNK,  modern,  ventral,  became,  and,  or,  berklee,
# Nearest to eight: nine,  six,  five,  seven,  four,  three,  zero,  one,
# Average loss at step  35000 :  4.077064296960831
# Nearest to was: is,  by,  are,  were,  has,  as,  and,  had,
# Nearest to one: two,  four,  three,  eight,  six,  five,  seven,  nine,
# Nearest to in: from,  and,  at,  for,  on,  of,  by,  nine,
# Nearest to th: four,  six,  two,  eight,  one,  three,  five,  seven,
# Nearest to would: can,  to,  were,  may,  was,  are,  is,  those,
# Nearest to been: was,  by,  were,  are,  strong,  become,  is,  an,
# Nearest to zero: five,  eight,  six,  four,  three,  seven,  two,  nine,
# Nearest to who: also,  that,  and,  not,  which,  this,  they,  he,
# Nearest to UNK: one,  and,  two,  three,  four,  seven,  five,  six,
# Nearest to an: the,  it,  his,  this,  one,  a,  which,  its,
# Nearest to known: a,  schwerin,  it,  which,  keegan,  adair,  much,  one,
# Nearest to however: in,  and,  was,  is,  four,  six,  shaolin,  on,
# Nearest to are: were,  is,  was,  and,  or,  have,  but,  in,
# Nearest to system: and,  a,  UNK,  each,  this,  number,  fulk,  epimenides,
# Nearest to over: sea,  UNK,  modern,  ventral,  and,  became,  or,  seven,
# Nearest to eight: nine,  six,  five,  seven,  four,  three,  zero,  two,
# Average loss at step  36000 :  3.9359772671461104
# Nearest to was: is,  by,  are,  has,  were,  as,  had,  and,
# Nearest to one: two,  three,  six,  four,  seven,  eight,  five,  UNK,
# Nearest to in: from,  and,  at,  for,  on,  of,  with,  nine,
# Nearest to th: four,  six,  two,  eight,  one,  three,  seven,  five,
# Nearest to would: can,  to,  were,  may,  was,  is,  are,  those,
# Nearest to been: was,  by,  were,  are,  strong,  become,  is,  be,
# Nearest to zero: five,  eight,  six,  three,  two,  seven,  four,  nine,
# Nearest to who: also,  that,  and,  not,  which,  this,  they,  he,
# Nearest to UNK: one,  and,  two,  seven,  three,  four,  six,  five,
# Nearest to an: the,  it,  this,  one,  his,  which,  a,  its,
# Nearest to known: a,  schwerin,  it,  which,  one,  keegan,  adair,  much,
# Nearest to however: and,  in,  was,  is,  six,  four,  for,  shaolin,
# Nearest to are: were,  is,  was,  and,  or,  have,  but,  by,
# Nearest to system: a,  UNK,  this,  each,  number,  fulk,  and,  epimenides,
# Nearest to over: sea,  ventral,  modern,  became,  UNK,  and,  or,  three,
# Nearest to eight: nine,  six,  seven,  five,  four,  three,  two,  zero,
# Average loss at step  37000 :  3.9025847899913786
# Nearest to was: is,  by,  are,  has,  were,  had,  as,  in,
# Nearest to one: two,  three,  four,  eight,  seven,  six,  five,  UNK,
# Nearest to in: and,  from,  at,  for,  on,  of,  nine,  with,
# Nearest to th: four,  two,  eight,  six,  three,  seven,  five,  one,
# Nearest to would: can,  to,  may,  were,  was,  are,  is,  those,
# Nearest to been: was,  by,  were,  are,  strong,  become,  be,  is,
# Nearest to zero: five,  eight,  six,  three,  seven,  two,  four,  nine,
# Nearest to who: also,  that,  and,  not,  which,  this,  it,  they,
# Nearest to UNK: one,  and,  two,  four,  three,  seven,  six,  or,
# Nearest to an: the,  it,  this,  one,  his,  which,  a,  its,
# Nearest to known: a,  schwerin,  it,  which,  keegan,  adair,  one,  much,
# Nearest to however: and,  in,  was,  is,  for,  shaolin,  four,  produced,
# Nearest to are: were,  is,  was,  or,  and,  have,  but,  in,
# Nearest to system: this,  UNK,  and,  a,  fulk,  each,  number,  epimenides,
# Nearest to over: sea,  ventral,  and,  modern,  UNK,  became,  berklee,  seven,
# Nearest to eight: nine,  six,  seven,  five,  four,  three,  zero,  two,
# Average loss at step  38000 :  3.842853677868843
# Nearest to was: is,  has,  by,  were,  are,  had,  and,  in,
# Nearest to one: two,  four,  three,  six,  five,  eight,  seven,  UNK,
# Nearest to in: and,  from,  at,  on,  for,  of,  by,  with,
# Nearest to th: four,  two,  six,  eight,  three,  five,  seven,  one,
# ...
# Nearest to UNK: five,  four,  three,  seven,  six,  two,  and,  or,
# Nearest to an: the,  this,  it,  one,  its,  coens,  no,  their,
# Nearest to known: such,  used,  a,  it,  schwerin,  seen,  described,  many,
# Nearest to however: but,  and,  in,  when,  that,  while,  is,  UNK,
# Nearest to are: were,  is,  have,  but,  was,  be,  zero,  or,
# Nearest to system: number,  it,  this,  UNK,  fulk,  name,  eventually,  world,
# Nearest to over: into,  at,  in,  sea,  eight,  ventral,  four,  six,
# Nearest to eight: seven,  six,  four,  five,  nine,  three,  zero,  two,
# Average loss at step  88000 :  3.22996446454525
# Nearest to was: is,  has,  were,  had,  by,  but,  are,  s,
# Nearest to one: seven,  two,  four,  three,  six,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  of,  for,  nine,  with,
# Nearest to th: six,  three,  four,  seven,  five,  two,  nine,  one,
# Nearest to would: can,  may,  will,  could,  to,  but,  was,  were,
# Nearest to been: was,  were,  be,  become,  by,  being,  strong,  had,
# Nearest to zero: five,  four,  eight,  six,  seven,  two,  three,  nine,
# Nearest to who: he,  also,  which,  they,  that,  often,  not,  and,
# Nearest to UNK: five,  four,  three,  seven,  one,  six,  two,  eight,
# Nearest to an: the,  this,  it,  one,  its,  coens,  no,  their,
# Nearest to known: such,  used,  a,  it,  schwerin,  seen,  described,  many,
# Nearest to however: but,  in,  when,  and,  that,  while,  which,  is,
# Nearest to are: were,  is,  have,  but,  was,  be,  or,  and,
# Nearest to system: number,  this,  it,  systems,  or,  not,  name,  zero,
# Nearest to over: into,  at,  eight,  in,  sea,  four,  ventral,  nine,
# Nearest to eight: seven,  six,  nine,  four,  five,  three,  two,  zero,
# Average loss at step  89000 :  3.0224180744886397
# Nearest to was: is,  has,  were,  had,  by,  but,  are,  been,
# Nearest to one: seven,  four,  two,  six,  three,  five,  eight,  zero,
# Nearest to in: at,  and,  from,  on,  of,  for,  nine,  however,
# Nearest to th: six,  three,  four,  five,  two,  seven,  one,  nine,
# Nearest to would: can,  may,  will,  could,  to,  but,  was,  were,
# Nearest to been: was,  were,  be,  become,  by,  being,  strong,  are,
# Nearest to zero: five,  four,  six,  seven,  eight,  three,  two,  nine,
# Nearest to who: he,  also,  which,  they,  that,  often,  and,  not,
# Nearest to UNK: five,  four,  seven,  three,  six,  one,  and,  two,
# Nearest to an: the,  this,  it,  its,  coens,  no,  one,  their,
# Nearest to known: such,  used,  a,  it,  seen,  described,  schwerin,  many,
# Nearest to however: but,  in,  and,  when,  that,  while,  is,  which,
# Nearest to are: were,  is,  but,  have,  was,  and,  or,  be,
# Nearest to system: number,  this,  or,  systems,  it,  fulk,  name,  not,
# Nearest to over: into,  in,  at,  four,  sea,  ventral,  eight,  nine,
# Nearest to eight: seven,  six,  four,  nine,  five,  three,  two,  zero,
# Average loss at step  90000 :  3.027436799526215
# Nearest to was: is,  has,  were,  had,  by,  but,  are,  been,
# Nearest to one: two,  four,  seven,  three,  six,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  nine,  of,  for,  eight,
# Nearest to th: six,  four,  three,  five,  seven,  two,  nine,  eight,
# Nearest to would: can,  may,  will,  could,  to,  but,  did,  was,
# Nearest to been: was,  were,  be,  become,  by,  being,  are,  strong,
# Nearest to zero: five,  four,  six,  seven,  eight,  three,  nine,  two,
# Nearest to who: he,  also,  which,  they,  that,  often,  not,  there,
# Nearest to UNK: three,  five,  four,  and,  seven,  six,  or,  two,
# Nearest to an: the,  this,  it,  its,  no,  or,  coens,  their,
# Nearest to known: such,  used,  a,  it,  seen,  schwerin,  described,  many,
# Nearest to however: but,  in,  when,  and,  that,  while,  which,  is,
# Nearest to are: were,  is,  have,  but,  was,  be,  or,  had,
# Nearest to system: number,  or,  this,  systems,  it,  and,  UNK,  fulk,
# Nearest to over: into,  in,  at,  eight,  four,  ventral,  sea,  nine,
# Nearest to eight: seven,  six,  nine,  four,  five,  three,  zero,  two,
# Average loss at step  91000 :  2.9742066596746444
# Nearest to was: is,  has,  were,  had,  by,  but,  are,  been,
# Nearest to one: two,  four,  seven,  six,  three,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  nine,  of,  with,  eight,
# Nearest to th: six,  four,  three,  five,  seven,  nine,  two,  one,
# Nearest to would: can,  may,  will,  could,  to,  but,  might,  was,
# Nearest to been: was,  were,  be,  become,  by,  being,  are,  strong,
# Nearest to zero: five,  six,  four,  seven,  eight,  three,  two,  nine,
# Nearest to who: he,  also,  which,  they,  that,  often,  not,  there,
# Nearest to UNK: four,  five,  three,  six,  seven,  one,  two,  eight,
# Nearest to an: the,  this,  it,  its,  no,  coens,  some,  their,
# Nearest to known: such,  used,  a,  it,  seen,  described,  schwerin,  many,
# Nearest to however: but,  when,  that,  in,  and,  while,  is,  which,
# Nearest to are: were,  is,  have,  but,  was,  be,  or,  had,
# Nearest to system: number,  systems,  this,  it,  fulk,  or,  four,  name,
# Nearest to over: into,  eight,  four,  at,  seven,  nine,  in,  ventral,
# Nearest to eight: seven,  six,  nine,  five,  four,  three,  zero,  two,
# Average loss at step  92000 :  2.8955306471586226
# Nearest to was: is,  has,  were,  had,  by,  but,  are,  been,
# Nearest to one: two,  four,  seven,  six,  three,  eight,  five,  nine,
# Nearest to in: at,  from,  on,  and,  for,  of,  with,  nine,
# Nearest to th: six,  four,  three,  five,  seven,  nine,  one,  two,
# Nearest to would: can,  may,  will,  could,  to,  might,  but,  did,
# Nearest to been: was,  were,  be,  become,  by,  being,  are,  strong,
# Nearest to zero: five,  six,  four,  eight,  seven,  three,  nine,  two,
# Nearest to who: he,  also,  which,  they,  often,  that,  not,  there,
# Nearest to UNK: three,  five,  one,  four,  seven,  six,  two,  and,
# Nearest to an: the,  this,  it,  one,  coens,  its,  no,  their,
# Nearest to known: such,  used,  a,  it,  seen,  schwerin,  described,  many,
# Nearest to however: but,  when,  and,  that,  in,  while,  which,  is,
# Nearest to are: were,  is,  but,  have,  was,  or,  be,  and,
# Nearest to system: number,  systems,  fulk,  this,  and,  or,  it,  name,
# Nearest to over: into,  eight,  four,  seven,  five,  nine,  three,  at,
# Nearest to eight: seven,  six,  nine,  five,  four,  three,  two,  zero,
# Average loss at step  93000 :  3.0422616450786593
# Nearest to was: is,  has,  had,  were,  by,  but,  are,  been,
# Nearest to one: two,  four,  six,  seven,  three,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  nine,  of,  eight,  with,
# Nearest to th: six,  four,  two,  nine,  five,  seven,  one,  three,
# Nearest to would: can,  may,  will,  could,  to,  might,  but,  did,
# Nearest to been: was,  were,  become,  be,  by,  being,  had,  strong,
# Nearest to zero: five,  six,  four,  seven,  eight,  three,  nine,  two,
# Nearest to who: he,  also,  which,  they,  often,  and,  that,  not,
# Nearest to UNK: five,  four,  three,  seven,  six,  eight,  two,  and,
# Nearest to an: the,  this,  it,  no,  its,  one,  coens,  some,
# Nearest to known: such,  used,  a,  it,  seen,  schwerin,  described,  many,
# Nearest to however: but,  when,  and,  that,  in,  while,  which,  is,
# Nearest to are: were,  is,  but,  have,  was,  or,  be,  and,
# Nearest to system: number,  systems,  this,  fulk,  or,  and,  name,  it,
# Nearest to over: into,  eight,  four,  seven,  five,  nine,  ventral,  six,
# Nearest to eight: seven,  six,  four,  five,  nine,  three,  two,  zero,
# Average loss at step  94000 :  3.163426409125328
# Nearest to was: is,  has,  had,  were,  by,  but,  been,  are,
# Nearest to one: two,  four,  six,  seven,  three,  five,  eight,  zero,
# Nearest to in: at,  and,  from,  on,  of,  nine,  eight,  for,
# Nearest to th: six,  four,  five,  two,  seven,  one,  nine,  three,
# Nearest to would: can,  may,  will,  could,  to,  might,  but,  did,
# Nearest to been: was,  were,  become,  be,  by,  being,  had,  strong,
# Nearest to zero: five,  six,  four,  seven,  eight,  three,  nine,  two,
# Nearest to who: he,  also,  which,  they,  often,  not,  that,  there,
# Nearest to UNK: five,  three,  four,  seven,  six,  two,  eight,  and,
# Nearest to an: the,  this,  it,  no,  its,  or,  one,  his,
# Nearest to known: such,  used,  a,  seen,  it,  schwerin,  described,  many,
# Nearest to however: but,  and,  when,  that,  while,  in,  which,  is,
# Nearest to are: were,  is,  have,  but,  was,  or,  be,  and,
# Nearest to system: number,  UNK,  systems,  fulk,  this,  or,  name,  and,
# Nearest to over: into,  eight,  four,  ventral,  seven,  five,  in,  sea,
# Nearest to eight: seven,  six,  nine,  five,  four,  three,  zero,  two,
# Average loss at step  95000 :  3.0736037313938143
# Nearest to was: is,  has,  had,  were,  by,  but,  are,  been,
# Nearest to one: two,  four,  six,  seven,  five,  three,  eight,  zero,
# Nearest to in: at,  from,  on,  and,  nine,  for,  eight,  of,
# Nearest to th: six,  five,  four,  three,  one,  seven,  nine,  two,
# Nearest to would: can,  may,  will,  could,  to,  but,  did,  might,
# Nearest to been: was,  were,  become,  be,  by,  being,  strong,  had,
# Nearest to zero: five,  four,  six,  seven,  eight,  three,  two,  nine,
# Nearest to who: he,  also,  which,  they,  often,  that,  not,  there,
# Nearest to UNK: four,  five,  three,  two,  six,  seven,  one,  eight,
# Nearest to an: the,  this,  it,  no,  its,  or,  coens,  merges,
# Nearest to known: such,  used,  a,  it,  seen,  schwerin,  described,  some,
# Nearest to however: but,  when,  in,  and,  that,  while,  which,  is,
# Nearest to are: were,  is,  have,  but,  was,  or,  be,  and,
# Nearest to system: UNK,  number,  systems,  and,  this,  name,  fulk,  eventually,
# Nearest to over: into,  eight,  four,  seven,  ventral,  three,  in,  five,
# Nearest to eight: seven,  nine,  six,  five,  four,  three,  zero,  two,
# Average loss at step  96000 :  3.093552906632423
# Nearest to was: is,  had,  has,  were,  by,  but,  in,  are,
# Nearest to one: two,  four,  six,  three,  seven,  five,  eight,  UNK,
# Nearest to in: at,  on,  from,  and,  nine,  for,  during,  eight,
# Nearest to th: six,  five,  four,  three,  nine,  two,  one,  seven,
# Nearest to would: can,  may,  will,  could,  to,  might,  did,  but,
# Nearest to been: were,  was,  be,  become,  by,  being,  had,  strong,
# Nearest to zero: four,  five,  six,  seven,  three,  eight,  nine,  two,
# Nearest to who: he,  also,  which,  they,  often,  that,  not,  there,
# Nearest to UNK: four,  five,  three,  seven,  six,  two,  one,  eight,
# Nearest to an: the,  this,  it,  its,  no,  or,  coens,  some,
# Nearest to known: such,  used,  a,  it,  seen,  described,  schwerin,  some,
# Nearest to however: but,  and,  when,  in,  that,  while,  which,  is,
# Nearest to are: were,  is,  but,  have,  was,  or,  be,  other,
# Nearest to system: number,  and,  UNK,  systems,  this,  name,  fulk,  or,
# Nearest to over: into,  eight,  four,  seven,  three,  ventral,  five,  and,
# Nearest to eight: seven,  nine,  six,  five,  four,  three,  two,  zero,
# Average loss at step  97000 :  3.1415594458580016
# Nearest to was: is,  had,  has,  were,  by,  but,  been,  are,
# Nearest to one: four,  two,  six,  three,  seven,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  of,  nine,  eight,  by,
# Nearest to th: six,  four,  five,  one,  nine,  three,  two,  seven,
# Nearest to would: can,  may,  will,  could,  to,  might,  but,  did,
# Nearest to been: were,  was,  be,  become,  by,  being,  had,  strong,
# Nearest to zero: five,  four,  six,  seven,  eight,  three,  nine,  two,
# Nearest to who: he,  also,  which,  they,  often,  that,  not,  there,
# Nearest to UNK: four,  three,  five,  seven,  six,  two,  eight,  one,
# Nearest to an: the,  this,  it,  its,  no,  or,  some,  coens,
# Nearest to known: such,  used,  a,  seen,  it,  described,  schwerin,  some,
# Nearest to however: but,  when,  and,  in,  that,  while,  which,  is,
# Nearest to are: were,  is,  but,  have,  was,  be,  or,  although,
# Nearest to system: number,  systems,  UNK,  and,  name,  this,  fulk,  or,
# Nearest to over: into,  eight,  four,  three,  seven,  ventral,  in,  on,
# Nearest to eight: seven,  nine,  six,  five,  four,  three,  two,  zero,
# Average loss at step  98000 :  3.052813206911087
# Nearest to was: is,  has,  had,  were,  by,  but,  are,  been,
# Nearest to one: four,  two,  six,  seven,  three,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  nine,  eight,  by,  of,
# Nearest to th: six,  one,  five,  four,  two,  three,  nine,  seven,
# Nearest to would: can,  may,  will,  could,  to,  but,  did,  might,
# Nearest to been: were,  was,  become,  be,  by,  being,  had,  strong,
# Nearest to zero: five,  four,  six,  seven,  three,  eight,  two,  nine,
# Nearest to who: he,  also,  they,  which,  often,  that,  not,  there,
# Nearest to UNK: four,  three,  five,  and,  seven,  six,  or,  one,
# Nearest to an: the,  this,  it,  its,  no,  coens,  merges,  some,
# Nearest to known: such,  used,  a,  seen,  it,  described,  schwerin,  some,
# Nearest to however: but,  when,  and,  that,  while,  which,  in,  although,
# Nearest to are: were,  is,  but,  have,  was,  be,  or,  although,
# Nearest to system: UNK,  number,  systems,  name,  fulk,  and,  this,  or,
# Nearest to over: into,  four,  eight,  three,  ventral,  seven,  in,  about,
# Nearest to eight: seven,  nine,  six,  five,  four,  three,  two,  zero,
# Average loss at step  99000 :  3.0652843465805053
# Nearest to was: is,  has,  had,  were,  by,  but,  been,  are,
# Nearest to one: four,  six,  two,  seven,  three,  five,  eight,  nine,
# Nearest to in: at,  from,  on,  and,  of,  nine,  by,  eight,
# Nearest to th: six,  one,  four,  five,  two,  nine,  three,  seven,
# Nearest to would: can,  may,  will,  could,  to,  but,  did,  might,
# Nearest to been: were,  was,  be,  become,  by,  being,  had,  strong,
# Nearest to zero: five,  four,  six,  seven,  three,  eight,  two,  nine,
# Nearest to who: he,  also,  they,  which,  often,  that,  not,  there,
# Nearest to UNK: three,  four,  seven,  and,  five,  six,  or,  one,
# Nearest to an: the,  this,  it,  or,  its,  no,  some,  coens,
# Nearest to known: such,  used,  a,  seen,  described,  it,  schwerin,  some,
# Nearest to however: but,  when,  that,  and,  while,  in,  which,  although,
# Nearest to are: were,  is,  but,  have,  was,  be,  or,  all,
# Nearest to system: number,  systems,  UNK,  name,  this,  or,  and,  fulk,
# Nearest to over: into,  eight,  four,  three,  seven,  in,  ventral,  and,
# Nearest to eight: seven,  nine,  six,  four,  five,  three,  two,  zero,
# Average loss at step  100000 :  3.1026313383579254
# Nearest to was: is,  has,  had,  were,  by,  but,  are,  been,
# Nearest to one: two,  six,  four,  seven,  three,  five,  eight,  nine,
# Nearest to in: at,  from,  and,  on,  nine,  of,  during,  with,
# Nearest to th: six,  one,  four,  five,  three,  nine,  two,  seven,
# Nearest to would: can,  may,  will,  could,  to,  did,  might,  but,
# Nearest to been: were,  was,  be,  become,  by,  being,  had,  strong,
# Nearest to zero: five,  four,  six,  seven,  three,  eight,  nine,  two,
# Nearest to who: he,  also,  they,  which,  often,  that,  not,  there,
# Nearest to UNK: four,  three,  one,  and,  five,  seven,  two,  or,
# Nearest to an: the,  this,  it,  its,  one,  no,  or,  coens,
# Nearest to known: such,  used,  a,  seen,  described,  it,  schwerin,  part,
# Nearest to however: but,  when,  that,  and,  while,  in,  which,  although,
# Nearest to are: were,  is,  but,  have,  was,  be,  or,  had,
# Nearest to system: number,  UNK,  systems,  name,  this,  fulk,  or,  otters,
# Nearest to over: into,  eight,  four,  in,  seven,  three,  ventral,  about,
# Nearest to eight: seven,  nine,  six,  five,  four,  three,  zero,  two,
